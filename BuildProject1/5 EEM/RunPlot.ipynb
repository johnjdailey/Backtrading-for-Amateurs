# %%
import Trader
# Out:
# Starting Portfolio Value: 1000000.000000
# 2019-02-27, Close, 41.78
# 2019-02-28, Close, 41.24
# 2019-03-01, Close, 41.29
# 2019-03-04, Close, 41.34
# 2019-03-05, Close, 41.75
# 2019-03-06, Close, 41.52
# 2019-03-07, Close, 40.75
# 2019-03-07, BUY CREATE, 40.75
# 2019-03-08, BUY EXECUTED 40.27
# 2019-03-08, Close, 40.46
# 2019-03-11, Close, 41.22
# 2019-03-12, Close, 41.43
# 2019-03-13, Close, 41.48
# 2019-03-14, Close, 41.26
# 2019-03-15, Close, 41.86
# 2019-03-15, SELL CREATED 41.86
# 2019-03-18, SELL EXECUTED 42.16
# 2019-03-18, Close, 42.33
# 2019-03-19, Close, 42.35
# 2019-03-20, Close, 42.41
# 2019-03-21, Close, 42.47
# 2019-03-22, Close, 41.23
# 2019-03-25, Close, 41.33
# 2019-03-26, Close, 41.45
# 2019-03-27, Close, 41.00
# 2019-03-28, Close, 41.28
# 2019-03-29, Close, 41.70
# 2019-04-01, Close, 42.39
# 2019-04-02, Close, 42.26
# 2019-04-03, Close, 42.55
# 2019-04-04, Close, 42.81
# 2019-04-05, Close, 43.14
# 2019-04-08, Close, 43.14
# 2019-04-09, Close, 43.06
# ...
