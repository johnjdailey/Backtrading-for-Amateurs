# %%
import Trader
# Out:
# Starting Portfolio Value: 1000000.000000
# 2019-02-27, Close, 22.19
# 2019-02-27, BUY CREATE, 22.19
# 2019-02-28, BUY EXECUTED 22.2
# 2019-02-28, Close, 22.08
# 2019-03-01, Close, 21.55
# 2019-03-04, Close, 21.70
# 2019-03-05, Close, 21.82
# 2019-03-06, Close, 21.37
# 2019-03-07, Close, 21.64
# 2019-03-07, SELL CREATED 21.64
# 2019-03-08, SELL EXECUTED 22.05
# 2019-03-08, Close, 22.21
# 2019-03-11, Close, 22.13
# 2019-03-12, Close, 22.52
# 2019-03-13, Close, 22.70
# 2019-03-14, Close, 22.09
# 2019-03-15, Close, 22.14
# 2019-03-18, Close, 21.89
# 2019-03-19, Close, 21.97
# 2019-03-20, Close, 22.47
# 2019-03-21, Close, 22.59
# 2019-03-22, Close, 22.62
# 2019-03-25, Close, 23.10
# 2019-03-26, Close, 23.19
# 2019-03-27, Close, 22.85
# 2019-03-28, Close, 22.25
# 2019-03-28, BUY CREATE, 22.25
# 2019-03-29, BUY EXECUTED 22.45
# 2019-03-29, Close, 22.26
# 2019-04-01, Close, 21.81
# 2019-04-02, Close, 21.94
# 2019-04-03, Close, 21.91
# 2019-04-04, Close, 22.34
# 2019-04-05, Close, 22.27
# ...
