# %%
import Trader
# Out:
# Starting Portfolio Value: 1000000.000000
# 2019-02-27, Close, 307.80
# 2019-02-28, Close, 306.30
# 2019-03-01, Close, 282.20
# 2019-03-01, BUY CREATE, 282.20
# 2019-03-04, BUY EXECUTED 275.9
# 2019-03-04, Close, 293.70
# 2019-03-05, Close, 296.00
# 2019-03-06, Close, 312.00
# 2019-03-07, Close, 335.60
# 2019-03-08, Close, 339.90
# 2019-03-11, Close, 293.20
# 2019-03-11, SELL CREATED 293.2
# 2019-03-12, SELL EXECUTED 288.0
# 2019-03-12, Close, 279.00
# 2019-03-12, BUY CREATE, 279.00
# 2019-03-13, BUY EXECUTED 274.7
# 2019-03-13, Close, 272.60
# 2019-03-14, Close, 264.90
# 2019-03-15, Close, 256.00
# 2019-03-18, Close, 256.20
# 2019-03-19, Close, 261.20
# 2019-03-20, Close, 263.60
# 2019-03-20, SELL CREATED 263.6
# 2019-03-21, SELL EXECUTED 270.0
# 2019-03-21, Close, 256.80
# 2019-03-22, Close, 309.80
# 2019-03-25, Close, 310.20
# 2019-03-26, Close, 281.90
# 2019-03-27, Close, 287.50
# 2019-03-28, Close, 277.60
# 2019-03-29, Close, 261.50
# 2019-03-29, BUY CREATE, 261.50
# ...
