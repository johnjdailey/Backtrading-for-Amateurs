# %%
import Trader
# Out:
# Starting Portfolio Value: 1000000.000000
# 2019-02-27, Close, 10.84
# 2019-02-27, BUY CREATE, 10.84
# 2019-02-28, BUY EXECUTED 10.78
# 2019-02-28, Close, 10.35
# 2019-03-01, Close, 10.23
# 2019-03-04, Close, 10.34
# 2019-03-05, Close, 9.85
# 2019-03-06, Close, 9.07
# 2019-03-07, Close, 9.41
# 2019-03-07, SELL CREATED 9.41
# 2019-03-08, SELL EXECUTED 9.3
# 2019-03-08, Close, 9.55
# 2019-03-11, Close, 9.87
# 2019-03-12, Close, 9.73
# 2019-03-13, Close, 9.99
# 2019-03-14, Close, 10.27
# 2019-03-15, Close, 9.93
# 2019-03-18, Close, 10.17
# 2019-03-19, Close, 10.16
# 2019-03-20, Close, 10.19
# 2019-03-21, Close, 10.24
# 2019-03-22, Close, 9.95
# 2019-03-25, Close, 9.85
# 2019-03-25, BUY CREATE, 9.85
# 2019-03-26, BUY EXECUTED 9.92
# 2019-03-26, Close, 10.07
# 2019-03-27, Close, 9.93
# 2019-03-28, Close, 9.86
# 2019-03-29, Close, 9.96
# 2019-04-01, Close, 10.07
# 2019-04-02, Close, 10.21
# 2019-04-02, SELL CREATED 10.21
# 2019-04-03, SELL EXECUTED 10.23
# 2019-04-03, Close, 10.07
# ...
