# %%
import Trader
# Out:
# Starting Portfolio Value: 1000000.000000
# 2019-02-27, Close, 26.05
# 2019-02-27, BUY CREATE, 26.05
# 2019-02-28, BUY EXECUTED 26.06
# 2019-02-28, Close, 25.99
# 2019-03-01, Close, 26.15
# 2019-03-04, Close, 25.99
# 2019-03-05, Close, 25.89
# 2019-03-06, Close, 25.72
# 2019-03-07, Close, 25.46
# 2019-03-07, SELL CREATED 25.46
# 2019-03-08, SELL EXECUTED 25.17
# 2019-03-08, Close, 25.45
# 2019-03-08, BUY CREATE, 25.45
# 2019-03-11, BUY EXECUTED 25.57
# 2019-03-11, Close, 25.71
# 2019-03-12, Close, 25.77
# 2019-03-13, Close, 25.95
# 2019-03-14, Close, 26.04
# 2019-03-15, Close, 26.23
# 2019-03-18, Close, 26.49
# 2019-03-18, SELL CREATED 26.49
# 2019-03-19, SELL EXECUTED 26.64
# 2019-03-19, Close, 26.29
# 2019-03-20, Close, 25.74
# 2019-03-20, BUY CREATE, 25.74
# 2019-03-21, BUY EXECUTED 25.57
# 2019-03-21, Close, 25.67
# 2019-03-22, Close, 24.96
# 2019-03-25, Close, 24.85
# 2019-03-26, Close, 25.14
# 2019-03-27, Close, 25.04
# 2019-03-28, Close, 25.25
# 2019-03-28, SELL CREATED 25.25
# ...
