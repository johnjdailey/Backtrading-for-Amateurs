# %%
import Trader
# Out:
# Starting Portfolio Value: 1000000.000000
# 2019-02-27, Close, 2.90
# 2019-02-28, Close, 2.96
# 2019-03-01, Close, 3.13
# 2019-03-04, Close, 3.19
# 2019-03-05, Close, 3.14
# 2019-03-06, Close, 2.98
# 2019-03-06, BUY CREATE, 2.98
# 2019-03-07, BUY EXECUTED 3.0
# 2019-03-07, Close, 2.97
# 2019-03-08, Close, 2.73
# 2019-03-11, Close, 2.75
# 2019-03-12, Close, 2.88
# 2019-03-13, Close, 3.02
# 2019-03-14, Close, 3.10
# 2019-03-14, SELL CREATED 3.1
# 2019-03-15, SELL EXECUTED 3.07
# 2019-03-15, Close, 2.97
# 2019-03-18, Close, 3.15
# 2019-03-19, Close, 3.16
# 2019-03-20, Close, 3.26
# 2019-03-21, Close, 3.25
# 2019-03-22, Close, 3.12
# 2019-03-22, BUY CREATE, 3.12
# 2019-03-25, BUY EXECUTED 3.1
# 2019-03-25, Close, 3.10
# 2019-03-26, Close, 3.19
# 2019-03-27, Close, 3.19
# 2019-03-28, Close, 3.14
# 2019-03-29, Close, 3.10
# 2019-04-01, Close, 3.15
# 2019-04-01, SELL CREATED 3.15
# 2019-04-02, SELL EXECUTED 3.16
# 2019-04-02, Close, 3.20
# 2019-04-03, Close, 3.14
# 2019-04-04, Close, 3.21
# ...
