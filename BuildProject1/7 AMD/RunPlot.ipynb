# %%
import Trader
# Out:
# Starting Portfolio Value: 1000000.000000
# 2019-02-27, Close, 23.48
# 2019-02-27, BUY CREATE, 23.48
# 2019-02-28, BUY EXECUTED 23.21
# 2019-02-28, Close, 23.53
# 2019-03-01, Close, 23.68
# 2019-03-04, Close, 23.37
# 2019-03-05, Close, 23.50
# 2019-03-06, Close, 22.41
# 2019-03-07, Close, 22.08
# 2019-03-07, SELL CREATED 22.08
# 2019-03-08, SELL EXECUTED 21.35
# 2019-03-08, Close, 22.01
# 2019-03-08, BUY CREATE, 22.01
# 2019-03-11, BUY EXECUTED 22.15
# 2019-03-11, Close, 22.96
# 2019-03-12, Close, 23.49
# 2019-03-13, Close, 23.38
# 2019-03-14, Close, 22.82
# 2019-03-15, Close, 23.29
# 2019-03-18, Close, 23.25
# 2019-03-18, SELL CREATED 23.25
# 2019-03-19, SELL EXECUTED 23.6
# 2019-03-19, Close, 26.00
# 2019-03-20, Close, 25.70
# 2019-03-21, Close, 27.89
# 2019-03-22, Close, 26.37
# 2019-03-25, Close, 25.97
# 2019-03-25, BUY CREATE, 25.97
# 2019-03-26, BUY EXECUTED 26.69
# 2019-03-26, Close, 25.69
# 2019-03-27, Close, 24.89
# 2019-03-28, Close, 25.06
# 2019-03-29, Close, 25.52
# ...
