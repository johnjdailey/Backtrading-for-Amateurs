# %%
import Trader
# Out:
# Starting Portfolio Value: 1000000.000000
# 2019-02-27, Close, 8.24
# 2019-02-28, Close, 8.23
# 2019-03-01, Close, 8.25
# 2019-03-04, Close, 8.26
# 2019-03-05, Close, 8.23
# 2019-03-06, Close, 8.05
# 2019-03-06, BUY CREATE, 8.05
# 2019-03-07, BUY EXECUTED 8.03
# 2019-03-07, Close, 7.96
# 2019-03-08, Close, 7.90
# 2019-03-11, Close, 8.08
# 2019-03-12, Close, 8.04
# 2019-03-13, Close, 8.00
# 2019-03-14, Close, 7.89
# 2019-03-14, SELL CREATED 7.89
# 2019-03-15, SELL EXECUTED 7.9
# 2019-03-15, Close, 7.91
# 2019-03-18, Close, 8.04
# 2019-03-19, Close, 8.16
# 2019-03-20, Close, 7.98
# 2019-03-21, Close, 8.15
# 2019-03-22, Close, 8.01
# 2019-03-25, Close, 7.98
# 2019-03-25, BUY CREATE, 7.98
# 2019-03-26, BUY EXECUTED 8.01
# 2019-03-26, Close, 8.22
# 2019-03-27, Close, 8.09
# 2019-03-28, Close, 8.23
# 2019-03-29, Close, 8.24
# 2019-04-01, Close, 8.42
# 2019-04-02, Close, 8.45
# 2019-04-02, SELL CREATED 8.45
# 2019-04-03, SELL EXECUTED 8.51
# 2019-04-03, Close, 8.57
# 2019-04-04, Close, 8.67
# ...
